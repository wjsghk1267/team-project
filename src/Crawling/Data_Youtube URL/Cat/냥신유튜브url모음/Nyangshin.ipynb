# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# ChromeDriver 초기화
driver = webdriver.Chrome()

# 해당 페이지로 이동
driver.get('https://www.youtube.com/playlist?list=PL2PEbeRP1kQhr6WiE6nXNDyLR70O6ejzT')

# 페이지가 로드될 시간을 기다림
time.sleep(3)

# 모든 video-title 요소를 가져옴
video_titles = driver.find_elements(By.XPATH, '//*[@id="video-title"]')

# 데이터를 저장할 리스트
data = []

# 각 영상 제목과 href를 추출하여 리스트에 추가
for video in video_titles:
    title = video.get_attribute('title')  # 제목을 가져옴
    href = video.get_attribute('href')    # href 링크를 가져옴
    data.append({'제목': title, '링크': href})

# 데이터프레임 생성
df = pd.DataFrame(data)

# CSV 파일로 저장
df.to_csv('대집사 고양이 상담소.csv', index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("대집사 고양이 상담소.csv")
df
# Out:
#                                                    제목  \
# 0           고양이끼리 장난 ? 아님 싸움 ?? 구별법 알려드림 feat. 집사도 해당
# 1                     고양이도 과연 쥐가 날까? feat.쥐를 잡자 쥐를 잡자
# 2                        갑자기 고양이만 남겨진다면 ?  feat. 유산상속
# 3             강아지를 괴롭히는 고양이의 심리는 뭘까 ? feat. 자랑일까 고민일까
# 4   세계 최강 아기 고양이와 성묘의 합사 솔루션 feat.실제 영상 | 고양이 합사의 ...
# 5                         도대체 동생 수염을 뽑는 고양이 심리는 뭘까 ?!
# 6   갑자기 성격이 바뀐 고양이부터 자꾸 이상한게 나오는 고양이까지  ?  (냐옹신 고양...
# 7                     고양이들 싸움 좀 말려주세요. feat. 일촉즉발 영상들
# 8      오빠가 고양이를 때린다고요 ? | 고양이 고민에 관한 사소한 댓글까지 답해드립니다.
# 9              고양이마다 화가나는 순간들 feat.냥신은 매순간이 화 또는 짜증 ?
# 10                       하루 종일 쩝쩝대는 고양이, 이 질환을 의심해봐라!
# 11                       고양이한테 공격당해 응급실 갔어요 (상처 사진주의)
# 12               고양이한테 물려보지 못한 사람은 있어도 한 번만 물린 사람은 없다
# 13            고양이가 너무 울어서 집사도 울었다...영상 속 고양이가 운 진짜 이유
# 14                              고양이 초보집사들 동문회 열린 썰 푼다
# 15                                  당신의 고양이가 계속 우는 이유
# 16            집사 집에 가습기 있는지 없는지, 냥신이 고양이만 보고 알아채는 방법!
# 17               [ENG SUB] 코로나 때문에 고양이한테 분리불안이 생겼다고?!
# 18                             반려인과 수의사가 함께 책을 만들면???
# 19                 [ENG SUB] OMG!!! 고양이가 벌레를 먹어요!!!!!
# 20                 [ENG SUB] 고양이가 집사를 밟는 이유, 사랑해서라고?!
# 21                 고양이 장난감 쇼핑에 지친 그대들을 위해(우리는 통장 지킴이)
# 22                  [ENG SUB] 아픈 길 고양이를 그냥 지나칠 수 없을 때
# 23                          [ENG SUB] 고양이가 귀여운 과학적 이유
# 23  https://www.youtube.com/watch?v=HXlVS7QwFps&li...
# 24  https://www.youtube.com/watch?v=R0no4cC3zUI&li...
# 25  https://www.youtube.com/watch?v=m9t9tNjsOYA&li...
# 26  https://www.youtube.com/watch?v=euueW5igZi8&li...
# 27  https://www.youtube.com/watch?v=P-rMVZaL_Bk&li...
# 28  https://www.youtube.com/watch?v=TwjHlliZBg8&li...
# 29  https://www.youtube.com/watch?v=zbPY7Kp66cs&li...
# 30  https://www.youtube.com/watch?v=WOFrUIi74Fg&li...
# 31  https://www.youtube.com/watch?v=XLH8T0_c7fs&li...
# 32  https://www.youtube.com/watch?v=5UsVVqAVY9U&li...
# 33  https://www.youtube.com/watch?v=dm2s0-oGP64&li...
# 34  https://www.youtube.com/watch?v=puhZNwgv-20&li...
# 35  https://www.youtube.com/watch?v=05nhaglkkgI&li...
# 36  https://www.youtube.com/watch?v=2_knm-nWsYQ&li...
# 37  https://www.youtube.com/watch?v=C3bR9DfYl0g&li...
# 38  https://www.youtube.com/watch?v=HZ5ANYvRUeY&li...
# 39  https://www.youtube.com/watch?v=UaIZt03Rj8Q&li...
# 40  https://www.youtube.com/watch?v=Ns2ogVv_MHI&li...
# 41  https://www.youtube.com/watch?v=rkgipJ5maj0&li...
# 42  https://www.youtube.com/watch?v=VOT2-LRPjXM&li...
# 43  https://www.youtube.com/watch?v=AeEmJBYd90A&li...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# ChromeDriver 초기화
driver = webdriver.Chrome()

# 해당 페이지로 이동
driver.get('https://www.youtube.com/playlist?list=PLhLLGKcG94RMTaxlgxm7Vgr76ca3Zv5M0')

# 페이지가 로드될 시간을 기다림
time.sleep(3)

# 페이지 끝까지 스크롤을 내리는 함수
def scroll_to_bottom(driver):
    last_height = driver.execute_script("return document.documentElement.scrollHeight")
    while True:
        # 페이지의 맨 아래까지 스크롤
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        
        # 새로운 콘텐츠가 로드될 시간을 기다림
        time.sleep(2)

        # 스크롤 후 새로운 높이를 확인
        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        
        # 더 이상 새로운 콘텐츠가 없으면 스크롤을 멈춤
        if new_height == last_height:
            break
        
        last_height = new_height

# 페이지 끝까지 스크롤
scroll_to_bottom(driver)

# 모든 video-title 요소를 가져옴
video_titles = driver.find_elements(By.XPATH, '//*[@id="video-title"]')

# 데이터를 저장할 리스트
data = []

# 각 영상 제목과 href를 추출하여 리스트에 추가
for video in video_titles:
    title = video.get_attribute('title')  # 제목을 가져옴
    href = video.get_attribute('href')    # href 링크를 가져옴
    data.append({'제목': title, '링크': href})

# 데이터프레임 생성
df = pd.DataFrame(data)

# CSV 파일로 저장
df.to_csv('👨‍⚕️묘한 진료실.csv', index=False, encoding='utf-8-sig')

# 드라이버 종료
driver.quit()
